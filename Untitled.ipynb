# %%
import pandas as pd
import numpy as np
df=pd.read_csv('missing_values.csv')

# %%
print("df.head(5).append(df.tail(6))")
# Out:
# df.head(5).append(df.tail(6))

# %%
combined = pd.concat([df.head(5), df.tail(6)])
